# %%
import os
import pickle
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
# Precision, Recall, F1, and plot confusion matrix libs
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

if torch.cuda.is_available():
    device = torch.device("cuda")
    num_gpus = torch.cuda.device_count()
    print(f"Using CUDA (GPU) Available GPUs: {num_gpus}")
    
    # Display all available GPU devices
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    device = torch.device("cpu")
    print("Using CPU (No GPU detected)")

print(f"Running on device: {device}")
# Out:
# Using CUDA (GPU) Available GPUs: 1
# GPU 0: NVIDIA GeForce RTX 4080 SUPER
# Running on device: cuda

# %%
# Read CIFAR-10 batch file
def load_cifar10_train(root_dir):
    all_data = []
    all_labels = []
    for i in range(1, 6):
        file_name = os.path.join(root_dir, f"data_batch_{i}")
        with open(file_name, 'rb') as fo:
            data_dict = pickle.load(fo, encoding='bytes')
            # data_dict[b'data'] shape: (10000, 3072)
            # data_dict[b'labels'] length: 10000
            all_data.append(data_dict[b'data'])
            all_labels.append(data_dict[b'labels'])
            
    all_data = np.concatenate(all_data, axis=0)  # (50000, 3072)
    all_labels = np.concatenate(all_labels, axis=0)  # (50000,)
    
    # Convert numpy to torch.Tensor
    # reshape
    all_data = all_data.reshape(-1, 3, 32, 32).astype(np.float32)
    # tensor
    X_train = torch.from_numpy(all_data)  # shape: (50000, 3, 32, 32)
    y_train = torch.from_numpy(all_labels).long()  # shape: (50000,)
    
    return X_train, y_train

def load_cifar10_test(root_dir):
    file_name = os.path.join(root_dir, "test_batch")
    with open(file_name, 'rb') as fo:
        data_dict = pickle.load(fo, encoding='bytes')
        test_data = data_dict[b'data']  # shape: (10000, 3072)
        test_labels = data_dict[b'labels']  # list of length 10000
    
    test_data = test_data.reshape(-1, 3, 32, 32).astype(np.float32)
    X_test = torch.from_numpy(test_data)
    y_test = torch.tensor(test_labels, dtype=torch.long)
    
    return X_test, y_test

# %%
cifar_root = './datasets/cifar-10-batches-py'

# Loading training and testing data
X_train, y_train = load_cifar10_train(cifar_root)  # shape: (50000, 3, 32, 32), (50000,)
X_test, y_test   = load_cifar10_test(cifar_root)   # shape: (10000, 3, 32, 32), (10000,)

X_train = X_train.view(X_train.size(0), -1)  # (50000, 3072)
X_test  = X_test.view(X_test.size(0), -1)    # (10000, 3072)

# Use TensorDataset to directly pack (data, label)
train_dataset = TensorDataset(X_train, y_train)
test_dataset  = TensorDataset(X_test, y_test)

# Iterating in batches using DataLoader
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)
test_loader  = DataLoader(test_dataset, batch_size=128, shuffle=False)

# %%
class SimpleMLP(nn.Module):
    def __init__(self, input_dim=3072, hidden_dims=[512, 256, 128], num_classes=10):
        super().__init__()
        layers = []
        prev_dim = input_dim
        for h in hidden_dims:
            layers.append(nn.Linear(prev_dim, h))
            layers.append(nn.ReLU())
            prev_dim = h
        layers.append(nn.Linear(prev_dim, num_classes))
        
        self.model = nn.Sequential(*layers)
        
    def forward(self, x):
        # x shape: (batch_size, 3072)
        return self.model(x)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def train_epoch(model, loader, optimizer, criterion):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for images, labels in loader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * images.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)
    
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

def eval_epoch(model, loader, criterion):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            
            running_loss += loss.item() * images.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)
            
    epoch_loss = running_loss / total
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

# %%
# model = SimpleMLP(input_dim=3072, hidden_dims=[512,256,128], num_classes=10).to(device)
model = SimpleMLP(input_dim=3072, hidden_dims=[1024,512,256,128], num_classes=10).to(device)
# model = SimpleMLP(input_dim=3072, hidden_dims=[1024, 1024, 512, 256, 128], num_classes=10).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# num_epochs = 20
# num_epochs = 50
num_epochs = 100
train_losses, train_accuracies = [], []
test_losses, test_accuracies = [], []

for epoch in range(num_epochs):
    train_loss, train_acc = train_epoch(model, train_loader, optimizer, criterion)
    test_loss, test_acc   = eval_epoch(model, test_loader, criterion)
    
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)
    test_losses.append(test_loss)
    test_accuracies.append(test_acc)
    
    print(f"Epoch [{epoch+1}/{num_epochs}] "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
          f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}")
# Out:
# Epoch [1/100] Train Loss: 2.9503, Train Acc: 0.2604, Test Loss: 1.8323, Test Acc: 0.3346
# Epoch [2/100] Train Loss: 1.7671, Train Acc: 0.3625, Test Loss: 1.6779, Test Acc: 0.4036
# Epoch [3/100] Train Loss: 1.6728, Train Acc: 0.4016, Test Loss: 1.6210, Test Acc: 0.4188
# Epoch [4/100] Train Loss: 1.6111, Train Acc: 0.4215, Test Loss: 1.5657, Test Acc: 0.4448
# Epoch [5/100] Train Loss: 1.5744, Train Acc: 0.4360, Test Loss: 1.5466, Test Acc: 0.4412
# Epoch [6/100] Train Loss: 1.5342, Train Acc: 0.4514, Test Loss: 1.5302, Test Acc: 0.4537
# Epoch [7/100] Train Loss: 1.5224, Train Acc: 0.4585, Test Loss: 1.5741, Test Acc: 0.4339
# Epoch [8/100] Train Loss: 1.4934, Train Acc: 0.4670, Test Loss: 1.5089, Test Acc: 0.4601
# Epoch [9/100] Train Loss: 1.4772, Train Acc: 0.4712, Test Loss: 1.5251, Test Acc: 0.4654
# Epoch [10/100] Train Loss: 1.4634, Train Acc: 0.4777, Test Loss: 1.5006, Test Acc: 0.4705
# Epoch [11/100] Train Loss: 1.4491, Train Acc: 0.4825, Test Loss: 1.5343, Test Acc: 0.4610
# Epoch [12/100] Train Loss: 1.4223, Train Acc: 0.4927, Test Loss: 1.5259, Test Acc: 0.4625
# Epoch [13/100] Train Loss: 1.4240, Train Acc: 0.4928, Test Loss: 1.4703, Test Acc: 0.4814
# Epoch [14/100] Train Loss: 1.3996, Train Acc: 0.5004, Test Loss: 1.5256, Test Acc: 0.4557
# Epoch [15/100] Train Loss: 1.3882, Train Acc: 0.5055, Test Loss: 1.4746, Test Acc: 0.4760
# Epoch [16/100] Train Loss: 1.3715, Train Acc: 0.5113, Test Loss: 1.4518, Test Acc: 0.4916
# Epoch [17/100] Train Loss: 1.3603, Train Acc: 0.5181, Test Loss: 1.4470, Test Acc: 0.4811
# Epoch [18/100] Train Loss: 1.3457, Train Acc: 0.5205, Test Loss: 1.4447, Test Acc: 0.4940
# Epoch [19/100] Train Loss: 1.3351, Train Acc: 0.5233, Test Loss: 1.4733, Test Acc: 0.4802
# Epoch [20/100] Train Loss: 1.3174, Train Acc: 0.5315, Test Loss: 1.4450, Test Acc: 0.4960
# Epoch [21/100] Train Loss: 1.3105, Train Acc: 0.5311, Test Loss: 1.5973, Test Acc: 0.4475
# Epoch [22/100] Train Loss: 1.3002, Train Acc: 0.5334, Test Loss: 1.4517, Test Acc: 0.4878
# Epoch [23/100] Train Loss: 1.2813, Train Acc: 0.5423, Test Loss: 1.4588, Test Acc: 0.4842
# Epoch [24/100] Train Loss: 1.2792, Train Acc: 0.5424, Test Loss: 1.4395, Test Acc: 0.4910
# Epoch [25/100] Train Loss: 1.2736, Train Acc: 0.5460, Test Loss: 1.4623, Test Acc: 0.4921
# Epoch [26/100] Train Loss: 1.2542, Train Acc: 0.5499, Test Loss: 1.4686, Test Acc: 0.4858
# Epoch [27/100] Train Loss: 1.2434, Train Acc: 0.5565, Test Loss: 1.4880, Test Acc: 0.4849
# Epoch [28/100] Train Loss: 1.2331, Train Acc: 0.5590, Test Loss: 1.4450, Test Acc: 0.5074
# Epoch [29/100] Train Loss: 1.2275, Train Acc: 0.5602, Test Loss: 1.4524, Test Acc: 0.4916
# Epoch [30/100] Train Loss: 1.2256, Train Acc: 0.5606, Test Loss: 1.4411, Test Acc: 0.4975
# Epoch [31/100] Train Loss: 1.2159, Train Acc: 0.5634, Test Loss: 1.4658, Test Acc: 0.4912
# Epoch [32/100] Train Loss: 1.2007, Train Acc: 0.5718, Test Loss: 1.4763, Test Acc: 0.4948
# Epoch [33/100] Train Loss: 1.1910, Train Acc: 0.5724, Test Loss: 1.4831, Test Acc: 0.4991
# Epoch [34/100] Train Loss: 1.1823, Train Acc: 0.5792, Test Loss: 1.4940, Test Acc: 0.4925
# Epoch [35/100] Train Loss: 1.1763, Train Acc: 0.5779, Test Loss: 1.4548, Test Acc: 0.5036
# Epoch [36/100] Train Loss: 1.1652, Train Acc: 0.5819, Test Loss: 1.4789, Test Acc: 0.4987
# Epoch [37/100] Train Loss: 1.1485, Train Acc: 0.5897, Test Loss: 1.4983, Test Acc: 0.5006
# Epoch [38/100] Train Loss: 1.1472, Train Acc: 0.5893, Test Loss: 1.4863, Test Acc: 0.5016
# Epoch [39/100] Train Loss: 1.1390, Train Acc: 0.5901, Test Loss: 1.5200, Test Acc: 0.4922
# Epoch [40/100] Train Loss: 1.1233, Train Acc: 0.5955, Test Loss: 1.5121, Test Acc: 0.4937
# Epoch [41/100] Train Loss: 1.1146, Train Acc: 0.6025, Test Loss: 1.5170, Test Acc: 0.4973
# Epoch [42/100] Train Loss: 1.1183, Train Acc: 0.5989, Test Loss: 1.5658, Test Acc: 0.4901
# Epoch [43/100] Train Loss: 1.1099, Train Acc: 0.6008, Test Loss: 1.5280, Test Acc: 0.5003
# Epoch [44/100] Train Loss: 1.1139, Train Acc: 0.6000, Test Loss: 1.5083, Test Acc: 0.4973
# Epoch [45/100] Train Loss: 1.0945, Train Acc: 0.6078, Test Loss: 1.5439, Test Acc: 0.4947
# Epoch [46/100] Train Loss: 1.0849, Train Acc: 0.6114, Test Loss: 1.5693, Test Acc: 0.5054
# Epoch [47/100] Train Loss: 1.0832, Train Acc: 0.6121, Test Loss: 1.5522, Test Acc: 0.5012
# Epoch [48/100] Train Loss: 1.0753, Train Acc: 0.6169, Test Loss: 1.5558, Test Acc: 0.5050
# Epoch [49/100] Train Loss: 1.0628, Train Acc: 0.6186, Test Loss: 1.5313, Test Acc: 0.5015
# Epoch [50/100] Train Loss: 1.0553, Train Acc: 0.6223, Test Loss: 1.5786, Test Acc: 0.4966
# Epoch [51/100] Train Loss: 1.0637, Train Acc: 0.6178, Test Loss: 1.5803, Test Acc: 0.4959
# Epoch [52/100] Train Loss: 1.0473, Train Acc: 0.6266, Test Loss: 1.5754, Test Acc: 0.4934
# Epoch [53/100] Train Loss: 1.0417, Train Acc: 0.6291, Test Loss: 1.5823, Test Acc: 0.5000
# Epoch [54/100] Train Loss: 1.0396, Train Acc: 0.6292, Test Loss: 1.5974, Test Acc: 0.5020
# Epoch [55/100] Train Loss: 1.0261, Train Acc: 0.6301, Test Loss: 1.5727, Test Acc: 0.5016
# Epoch [56/100] Train Loss: 1.0129, Train Acc: 0.6368, Test Loss: 1.6777, Test Acc: 0.4780
# Epoch [57/100] Train Loss: 1.0222, Train Acc: 0.6341, Test Loss: 1.6381, Test Acc: 0.4961
# Epoch [58/100] Train Loss: 1.0118, Train Acc: 0.6368, Test Loss: 1.6370, Test Acc: 0.4935
# Epoch [59/100] Train Loss: 1.0043, Train Acc: 0.6413, Test Loss: 1.6356, Test Acc: 0.4988
# Epoch [60/100] Train Loss: 1.0002, Train Acc: 0.6437, Test Loss: 1.6769, Test Acc: 0.4885
# Epoch [61/100] Train Loss: 0.9976, Train Acc: 0.6427, Test Loss: 1.7187, Test Acc: 0.4810
# Epoch [62/100] Train Loss: 0.9954, Train Acc: 0.6438, Test Loss: 1.6950, Test Acc: 0.4918
# Epoch [63/100] Train Loss: 0.9862, Train Acc: 0.6484, Test Loss: 1.6340, Test Acc: 0.4913
# Epoch [64/100] Train Loss: 0.9835, Train Acc: 0.6486, Test Loss: 1.7099, Test Acc: 0.4911
# Epoch [65/100] Train Loss: 0.9812, Train Acc: 0.6504, Test Loss: 1.6819, Test Acc: 0.4889
# Epoch [66/100] Train Loss: 0.9856, Train Acc: 0.6474, Test Loss: 1.7153, Test Acc: 0.4943
# Epoch [67/100] Train Loss: 0.9740, Train Acc: 0.6503, Test Loss: 1.7572, Test Acc: 0.4858
# Epoch [68/100] Train Loss: 0.9664, Train Acc: 0.6551, Test Loss: 1.7283, Test Acc: 0.4917
# Epoch [69/100] Train Loss: 0.9568, Train Acc: 0.6570, Test Loss: 1.6954, Test Acc: 0.4977
# Epoch [70/100] Train Loss: 0.9657, Train Acc: 0.6573, Test Loss: 1.7326, Test Acc: 0.4946
# Epoch [71/100] Train Loss: 0.9513, Train Acc: 0.6602, Test Loss: 1.7191, Test Acc: 0.4951
# Epoch [72/100] Train Loss: 0.9560, Train Acc: 0.6562, Test Loss: 1.7088, Test Acc: 0.4930
# Epoch [73/100] Train Loss: 0.9469, Train Acc: 0.6628, Test Loss: 1.7892, Test Acc: 0.4836
# Epoch [74/100] Train Loss: 0.9585, Train Acc: 0.6589, Test Loss: 1.6940, Test Acc: 0.4897
# Epoch [75/100] Train Loss: 0.9216, Train Acc: 0.6702, Test Loss: 1.7452, Test Acc: 0.4884
# Epoch [76/100] Train Loss: 0.9395, Train Acc: 0.6655, Test Loss: 1.7628, Test Acc: 0.4917
# Epoch [77/100] Train Loss: 0.9342, Train Acc: 0.6659, Test Loss: 1.7403, Test Acc: 0.4896
# Epoch [78/100] Train Loss: 0.9248, Train Acc: 0.6697, Test Loss: 1.7990, Test Acc: 0.4845
# Epoch [79/100] Train Loss: 0.9204, Train Acc: 0.6696, Test Loss: 1.8738, Test Acc: 0.4768
# Epoch [80/100] Train Loss: 0.9085, Train Acc: 0.6763, Test Loss: 1.8131, Test Acc: 0.4897
# Epoch [81/100] Train Loss: 0.9118, Train Acc: 0.6754, Test Loss: 1.8626, Test Acc: 0.4897
# Epoch [82/100] Train Loss: 0.8970, Train Acc: 0.6813, Test Loss: 1.8771, Test Acc: 0.4840
# Epoch [83/100] Train Loss: 0.9169, Train Acc: 0.6732, Test Loss: 1.8406, Test Acc: 0.4859
# Epoch [84/100] Train Loss: 0.9065, Train Acc: 0.6771, Test Loss: 1.8022, Test Acc: 0.4907
# Epoch [85/100] Train Loss: 0.9210, Train Acc: 0.6725, Test Loss: 1.7965, Test Acc: 0.4899
# Epoch [86/100] Train Loss: 0.8973, Train Acc: 0.6812, Test Loss: 1.8012, Test Acc: 0.4925
# Epoch [87/100] Train Loss: 0.8776, Train Acc: 0.6855, Test Loss: 1.8755, Test Acc: 0.4927
# Epoch [88/100] Train Loss: 0.8765, Train Acc: 0.6865, Test Loss: 1.8996, Test Acc: 0.4951
# Epoch [89/100] Train Loss: 0.8911, Train Acc: 0.6849, Test Loss: 1.8409, Test Acc: 0.4906
# Epoch [90/100] Train Loss: 0.8724, Train Acc: 0.6879, Test Loss: 1.9252, Test Acc: 0.4883
# Epoch [91/100] Train Loss: 0.8671, Train Acc: 0.6901, Test Loss: 1.9146, Test Acc: 0.4868
# Epoch [92/100] Train Loss: 0.8631, Train Acc: 0.6944, Test Loss: 1.8663, Test Acc: 0.4891
# Epoch [93/100] Train Loss: 0.8709, Train Acc: 0.6910, Test Loss: 1.9090, Test Acc: 0.4949
# Epoch [94/100] Train Loss: 0.8742, Train Acc: 0.6912, Test Loss: 1.8874, Test Acc: 0.4841
# Epoch [95/100] Train Loss: 0.8733, Train Acc: 0.6911, Test Loss: 1.8984, Test Acc: 0.4976
# Epoch [96/100] Train Loss: 0.8511, Train Acc: 0.6995, Test Loss: 1.8551, Test Acc: 0.4952
# Epoch [97/100] Train Loss: 0.8562, Train Acc: 0.6958, Test Loss: 1.9647, Test Acc: 0.4884
# Epoch [98/100] Train Loss: 0.8593, Train Acc: 0.6951, Test Loss: 1.9324, Test Acc: 0.4884
# Epoch [99/100] Train Loss: 0.8400, Train Acc: 0.7023, Test Loss: 1.9779, Test Acc: 0.4831
# Epoch [100/100] Train Loss: 0.8533, Train Acc: 0.6976, Test Loss: 1.9120, Test Acc: 0.4909

# %%
plt.figure(figsize=(12, 5))

# Plotting the Loss Curve
plt.subplot(1, 2, 1)
plt.plot(range(1, num_epochs + 1), train_losses, label='Train Loss', marker='o')
plt.plot(range(1, num_epochs + 1), test_losses, label='Test Loss', marker='s')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Training & Validation Loss")

# Plotting the Accuracy Curve
plt.subplot(1, 2, 2)
plt.plot(range(1, num_epochs + 1), train_accuracies, label='Train Accuracy', marker='o')
plt.plot(range(1, num_epochs + 1), test_accuracies, label='Test Accuracy', marker='s')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Training & Validation Accuracy")

plt.show()

# %%
def compute_metrics(model, loader):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)
            all_preds.extend(predicted.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    precision = precision_score(all_labels, all_preds, average='macro')
    recall = recall_score(all_labels, all_preds, average='macro')
    f1 = f1_score(all_labels, all_preds, average='macro')
    cm = confusion_matrix(all_labels, all_preds)
    
    return precision, recall, f1, cm

# Calculate the final results of various indicators
precision, recall, f1, cm = compute_metrics(model, test_loader)

# Output indicators
print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1: {f1:.4f}")

# Plotting Confusion Matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap="Blues", xticklabels=range(10), yticklabels=range(10))
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Precision: 0.5024, Recall: 0.4909, F1: 0.4891
